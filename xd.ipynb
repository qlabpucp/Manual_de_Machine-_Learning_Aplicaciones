# %%
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn
# !pip install matplotlib
# !pip install seaborn
# !pip install jupyter
# !pip install pyreadstat
# Out:
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 31.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ----------------------- ---------------- 7.1/12.3 MB 33.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 42.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 10.2/10.2 MB 90.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 76.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 14.3/14.3 MB 89.9 MB/s eta 0:00:00
# ...
#
#    - --------------------------------------  2/62 [websocket-client]
#    - --------------------------------------  2/62 [websocket-client]
# ...
